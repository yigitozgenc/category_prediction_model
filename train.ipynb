# %%
from graph_helper import *
import pandas as pd
import numpy as np
from bertopic import bertopic
import pickle
# Out:
# /Users/mehmetyigitozgenc/miniconda3/envs/logiwa/category_predictor/graph_helper.py:19: DtypeWarning: Columns (1,2,4,6,7,12,13,15,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("ProductData.csv")

# %%
df = pd.read_csv("ProductData.csv")
# Out:
# /var/folders/p8/zlxsxl_n22b5jch7hn117pf80000gn/T/ipykernel_11643/1016749824.py:1: DtypeWarning: Columns (1,2,4,6,7,12,13,15,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("ProductData.csv")

# %%
categories = category_condition(df)

# %%
root,all_leafs = creating_cat_graph(categories,bertopic)

# %%
show_category_graph(root)
# Out:
# Categories
# ├── led double-sided sign tube
# │   └── 360°
# ├── home & garden
# │   ├── food & beverages
# │   │   ├── non-alcoholic drinks
# │   │   │   ├── tea & infusions
# │   │   │   │   ├── tea
# │   │   │   │   ├── salada
# │   │   │   │   ├── 20ct
# │   │   │   │   ├── teabags
# │   │   │   │   ├── iced
# │   │   │   │   ├── chai
# │   │   │   │   ├── tazo
# │   │   │   │   ├── guayaki
# │   │   │   │   ├── mate
# │   │   │   │   └── matcha
# │   │   │   └── juices, milkshakes & smoothies
# │   │   └── pantry
# │   │       └── jam, honey & spreads
# │   │           └── honey
# │   ├── kitchen, dining & bar
# │   │   ├── small kitchen appliances
# │   │   │   ├── waffle makers
# │   │   │   ├── countertop ice makers
# │   │   │   ├── grills & griddles
# │   │   │   └── coffee, tea & espresso makers
# │   │   │       ├── coffee grinders
# │   │   │       ├── pod & capsule coffee machines
# │   │   │       └── espresso & cappuccino machines
# │   │   ├── dinnerware & serveware
# ...
